# %%
# !pip install shimmy>=2.0
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
from stable_baselines3 import PPO
from snakeenv import *
# Out:
# Running cells with 'main (Python 3.12.6)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/Code/SnakeGame_ReinforcementLearning/main/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
Log_path = os.path.join("Training", "Logs")
PPO_path = os.path.join("Training", "Saved_Models")

# %%
env = SnakeEnv()
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=Log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\Subhradip\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
env.render_mode = 'human'
model.learn(total_timesteps=2000)
# Out:
# Logging to Training\Logs\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    fps             | 8        |
# |    iterations      | 1        |
# |    time_elapsed    | 251      |
# |    total_timesteps | 2048     |
# ---------------------------------

# %%
env.close()

# %%
env.render_mode = None
model.learn(total_timesteps=500000)
# Out:
# Logging to Training\Logs\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.26     |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    fps             | 2645     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.77        |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 1373        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015582561 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -9.51e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.03       |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.56        |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016592497 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 9.08e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 990         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1112        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012045609 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.000108   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 681         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 1.65e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.1       |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1082       |
# |    iterations           | 5          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01421468 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -1.55e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 506        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0204    |
# |    value_loss           | 1.18e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1060         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0091280965 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 1.13e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 771          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0113243535 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.905       |
# |    explained_variance   | -3.46e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 227          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 560          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.9        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016165731 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 4.95e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.8        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 329         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.8       |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1007       |
# |    iterations           | 9          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01410036 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.848     |
# |    explained_variance   | -8.11e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.7       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 196        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.4        |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010644776 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.8        |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 982         |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014957557 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 1.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 56.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 12          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.027376954 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.3         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 23.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.2        |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 13          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011394356 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.82        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.7        |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 14          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014999582 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.69        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.7        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 15          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008366999 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.71        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 17.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 16          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009973689 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.4        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 17          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009135277 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 18          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011570352 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 27          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 19          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011182822 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 28.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.2        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 20          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009726066 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 38.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.7         |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 21           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0072098034 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 45.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 22          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007573083 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.655      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.4        |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 23          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006881628 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 76.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.5         |
# |    ep_rew_mean          | -102         |
# | time/                   |              |
# |    fps                  | 942          |
# |    iterations           | 24           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0041672257 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00588     |
# |    value_loss           | 86.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 25          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006532356 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 93.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.8         |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 942          |
# |    iterations           | 26           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0050686793 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.0281       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00715     |
# |    value_loss           | 108          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.3       |
# |    ep_rew_mean          | -101       |
# | time/                   |            |
# |    fps                  | 942        |
# |    iterations           | 27         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00443547 |
# |    clip_fraction        | 0.06       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.631     |
# |    explained_variance   | 0.202      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 42         |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00571   |
# |    value_loss           | 104        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.5         |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 28           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0067788055 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.0459       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 118          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.8         |
# |    ep_rew_mean          | -100         |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 29           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0050501595 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.5         |
# |    ep_rew_mean          | -99.7        |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 30           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0073011345 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00817     |
# |    value_loss           | 105          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 31           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0068057096 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.0889       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 128          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 41.7      |
# |    ep_rew_mean          | -100      |
# | time/                   |           |
# |    fps                  | 937       |
# |    iterations           | 32        |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0077845 |
# |    clip_fraction        | 0.0779    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.561    |
# |    explained_variance   | 0.144     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 50.1      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -0.0058   |
# |    value_loss           | 123       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -97.7        |
# | time/                   |              |
# |    fps                  | 936          |
# |    iterations           | 33           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0064571807 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.6         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00545     |
# |    value_loss           | 132          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.6        |
# |    ep_rew_mean          | -97.8       |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 34          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008768471 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.0674      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00842    |
# |    value_loss           | 143         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.3         |
# |    ep_rew_mean          | -97.3        |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 35           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0066706967 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.091        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.7         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 147          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | -96.9       |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 36          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007115354 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.099       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 128         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.1         |
# |    ep_rew_mean          | -97.8        |
# | time/                   |              |
# |    fps                  | 935          |
# |    iterations           | 37           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0069161206 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | -0.0483      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.9         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | -99.2       |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 38          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007851567 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.6        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45          |
# |    ep_rew_mean          | -97.4       |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 39          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006567628 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.0326      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.7        |
# |    ep_rew_mean          | -97.8       |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 40          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008028243 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 134         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.2         |
# |    ep_rew_mean          | -98.2        |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 41           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0051229238 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.0394       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -96.7        |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 42           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0075523653 |
# |    clip_fraction        | 0.0852       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.8         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00517     |
# |    value_loss           | 139          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.9        |
# |    ep_rew_mean          | -95.1       |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 43          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005560406 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | -0.00142    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 163         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43           |
# |    ep_rew_mean          | -95.7        |
# | time/                   |              |
# |    fps                  | 935          |
# |    iterations           | 44           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0056797876 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.499       |
# |    explained_variance   | 0.0284       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.9         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 146          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | -96.5       |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 45          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011617297 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | -97.1       |
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 46          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006963607 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | -0.0659     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.6        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 156         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -97.2        |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 47           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0056545027 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.9         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49           |
# |    ep_rew_mean          | -96.2        |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 48           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0067947805 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.0382       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.8         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 155          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.1         |
# |    ep_rew_mean          | -94.3        |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 49           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0083559165 |
# |    clip_fraction        | 0.0895       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.0715       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.5         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 166          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.9        |
# |    ep_rew_mean          | -94.6       |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 50          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008927075 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.054       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.2        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.2        |
# |    ep_rew_mean          | -95.3       |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 51          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010276645 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | -96.6       |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 52          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006095738 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | -0.000917   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.2        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -6.45e-05   |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.1        |
# |    ep_rew_mean          | -95.6       |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 53          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.006723061 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.0567      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.4        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.8         |
# |    ep_rew_mean          | -93.4        |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 54           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0085517075 |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.0726       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 189          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 54.2       |
# |    ep_rew_mean          | -92        |
# | time/                   |            |
# |    fps                  | 921        |
# |    iterations           | 55         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.01020018 |
# |    clip_fraction        | 0.0686     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.437     |
# ...
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.9         |
# |    ep_rew_mean          | -85.2        |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 228          |
# |    time_elapsed         | 550          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0070423395 |
# |    clip_fraction        | 0.0804       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.29        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.7         |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | 0.00543      |
# |    value_loss           | 201          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -84.7      |
# | time/                   |            |
# |    fps                  | 847        |
# |    iterations           | 229        |
# |    time_elapsed         | 553        |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.01435102 |
# |    clip_fraction        | 0.0823     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.315     |
# |    explained_variance   | 0.0148     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 76.6       |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | -0.00205   |
# |    value_loss           | 198        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -84         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 230         |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.013925515 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.308      |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.5        |
# |    ep_rew_mean          | -83.8       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 231         |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.009240298 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | -0.0709     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.2        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 166         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -83.6        |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 232          |
# |    time_elapsed         | 560          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0074738865 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.000172    |
# |    value_loss           | 220          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -82.9       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 233         |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.008384666 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.0228      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.6        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 225         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -81.8        |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 234          |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0075596785 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | 0.0634       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 189          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -82.1       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 235         |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.006739729 |
# |    clip_fraction        | 0.0645      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | -0.0209     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.7        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 183         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -81.7       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 236         |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.010646015 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.5        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 283         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -82.8        |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 237          |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0065697394 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | -0.0358      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.3         |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 240          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | -83.1      |
# | time/                   |            |
# |    fps                  | 847        |
# |    iterations           | 238        |
# |    time_elapsed         | 574        |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.01888072 |
# |    clip_fraction        | 0.0657     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.259     |
# |    explained_variance   | 0.00516    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 98.1       |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.00386    |
# |    value_loss           | 269        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.4         |
# |    ep_rew_mean          | -84.8        |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 239          |
# |    time_elapsed         | 577          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0066644647 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | 0.0498       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | 0.00148      |
# |    value_loss           | 222          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 95.1       |
# |    ep_rew_mean          | -84.9      |
# | time/                   |            |
# |    fps                  | 847        |
# |    iterations           | 240        |
# |    time_elapsed         | 579        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.01049243 |
# |    clip_fraction        | 0.0701     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.274     |
# |    explained_variance   | -0.0791    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 103        |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | -0.00417   |
# |    value_loss           | 265        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -82.6       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 241         |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.010112272 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | -0.00124    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80          |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.00057     |
# |    value_loss           | 222         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -81         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 242         |
# |    time_elapsed         | 584         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.008856766 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | -0.111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92          |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | 0.00107     |
# |    value_loss           | 209         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | -83.8       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 243         |
# |    time_elapsed         | 587         |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.008188056 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.29       |
# |    explained_variance   | -0.0521     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.8        |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 206         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.1        |
# |    ep_rew_mean          | -85.8       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 244         |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.009597115 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.315      |
# |    explained_variance   | 0.0369      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.4        |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.5        |
# |    ep_rew_mean          | -86         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 245         |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.009509219 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.274      |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.2        |
# |    n_updates            | 2480        |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 201         |
# -----------------------------------------

# %%
model.save(PPO_path)

# %%
model = PPO.load(PPO_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\Subhradip\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
env.render_mode = 'human'
model.learn(total_timesteps=200)
# Out:
# Logging to Training\Logs\PPO_4
